# %%
from openai import OpenAI
import base64
import os
from PIL import Image

openai_apikey = os.getenv('OPENAI_APIKEY')
openai_organization = os.getenv('OPENAI_ORGANIZATION')

NumIterations = 40

client = OpenAI(
    organization=openai_organization,
    api_key=openai_apikey,  
)

# %%
def image_from_image(image_path):
    with open(image_path, "rb") as image_file:
        image_response = client.images.edit(
            image=image_file,
            model = "gpt-image-1",
            prompt="Please, please, please; provide me the same image as I'm uploading. Please keep track of all details on the image, the colors, the sizing, objects and more. "+ \
                "Check, double-check and triple-check if the provided image is indeed the same as the uploaded image.", # Please the AI model to make sure the Terminator doesn't come after me.
            size="1024x1024"
        )
    return image_response.data[0].b64_json

# %%
for i in range(0, NumIterations):
    print("Start image ",i)
    gen_picture = image_from_image(f"./PictureLoop/image_{i}.png")
    with open(f"./PictureLoop/image_{i+1}.png", "wb") as f:
        f.write(base64.b64decode(gen_picture))
# Out:
# Start image  0
# Start image  1
# Start image  2
# Start image  3
# Start image  4
# Start image  5
# Start image  6
# Start image  7
# Start image  8
# Start image  9
# Start image  10
# Start image  11
# Start image  12
# Start image  13
# Start image  14
# Start image  15
# Start image  16
# Start image  17
# Start image  18
# Start image  19
# Start image  20
# Start image  21
# Start image  22
# Start image  23
# Start image  24
# Start image  25
# Start image  26
# Start image  27
# Start image  28
# Start image  29
# Start image  30
# Start image  31
# Start image  32
# Start image  33
# Start image  34
# Start image  35
# Start image  36
# Start image  37
# Start image  38
# Start image  39
# Start image  40
# Start image  41
# Start image  42
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 3
#       1 for i in range(0, NumIterations):
# ...

# %%
output_gif = 'ImageEvolution.gif'

image_files = [f'image_{i}.png' for i in range(0,NumIterations)]
images = [Image.open(os.path.join('PictureLoop', img)) for img in image_files]

# Save as GIF
images[0].save(
    output_gif,
    save_all=True,
    append_images=images[1:],
    duration=500,   # duration per frame in milliseconds
    loop=0          # loop forever
)

print(f"GIF saved as {output_gif}")
# Out:
# GIF saved as ImageEvolution.gif
